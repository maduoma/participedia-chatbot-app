# %%
import pandas as pd

# %%
# Load the uploaded datasets
case_dataset_path = 'raw_data/Case Dataset.csv'
method_dataset_path = 'raw_data/Method Dataset.csv'

# Read the datasets
case_data = pd.read_csv(case_dataset_path)
method_data = pd.read_csv(method_dataset_path)

# Display the first few rows of each dataset to understand the structure and contents
case_data_head = case_data.head()
method_data_head = method_data.head()

# %%
# Check the column names and data types to understand the structure of each dataset
case_data_info = case_data.info()
method_data_info = method_data.info()

(case_data_head, method_data_head, case_data_info, method_data_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2259 entries, 0 to 2258
# Columns: 111 entries, id to collections
# dtypes: float64(9), int64(14), object(88)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           373 non-null    int64
#  1   type                         373 non-null    object
#  2   title                        373 non-null    object
#  3   url                          373 non-null    object
#  4   description                  356 non-null    object
#  5   featured                     373 non-null    int64
#  6   post_date                    373 non-null    object
#  7   updated_date                 373 non-null    object
#  8   creator_id                   373 non-null    int64
# ...

# %%
# Check the column names and data types to understand the structure of each dataset
case_data_info = case_data.info()
method_data_info = method_data.info()

(case_data_head, method_data_head, case_data_info, method_data_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2259 entries, 0 to 2258
# Columns: 111 entries, id to collections
# dtypes: float64(9), int64(14), object(88)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           373 non-null    int64
#  1   type                         373 non-null    object
#  2   title                        373 non-null    object
#  3   url                          373 non-null    object
#  4   description                  356 non-null    object
#  5   featured                     373 non-null    int64
#  6   post_date                    373 non-null    object
#  7   updated_date                 373 non-null    object
#  8   creator_id                   373 non-null    int64
# ...
